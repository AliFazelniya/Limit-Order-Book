# %%
from pathlib import Path
import pandas as pd

# %%
DATA_DIR = Path().resolve().parent / "data"
TEST_DATA_DIR = DATA_DIR / "testing"
TRAIN_DATA_DIR = DATA_DIR / "training"
SAMPLE_ROWS = 3

# %%
testing_datasets_list = [
    "Test_Dst_NoAuction_ZScore_CF_1.csv", 
    "Test_Dst_NoAuction_ZScore_CF_2.csv",
    "Test_Dst_NoAuction_ZScore_CF_3.csv",
    "Test_Dst_NoAuction_ZScore_CF_4.csv",
    "Test_Dst_NoAuction_ZScore_CF_5.csv",
    "Test_Dst_NoAuction_ZScore_CF_6.csv",
    "Test_Dst_NoAuction_ZScore_CF_7.csv",
    "Test_Dst_NoAuction_ZScore_CF_8.csv",
    "Test_Dst_NoAuction_ZScore_CF_9.csv"
]

training_datasets_list = [
    "Train_Dst_NoAuction_ZScore_CF_1.csv",
    "Train_Dst_NoAuction_ZScore_CF_2.csv",
    "Train_Dst_NoAuction_ZScore_CF_3.csv",
    "Train_Dst_NoAuction_ZScore_CF_4.csv",
    "Train_Dst_NoAuction_ZScore_CF_5.csv",
    "Train_Dst_NoAuction_ZScore_CF_6.csv",
    "Train_Dst_NoAuction_ZScore_CF_7.csv",
    "Train_Dst_NoAuction_ZScore_CF_8.csv",
    "Train_Dst_NoAuction_ZScore_CF_9.csv",
]

# %%
df = pd.read_csv(TEST_DATA_DIR / "Test_Dst_NoAuction_ZScore_CF_1.csv")
df.head()
# Out:
#    4.8382630e-01  4.8382630e-01.1  4.8280533e-01  4.8280533e-01.1  \
# 0      -0.411866        -0.411866      -0.515418        -0.182047
# 1       0.484376         0.484376       0.484376         0.484376
# 2      -0.462407        -0.462407      -0.462407        -0.462407
# 3       0.483370         0.483370       0.482350         0.483370
# 4      -0.368474        -0.368474      -0.408200        -0.293628
#
#    4.8280533e-01.2  4.8280533e-01.3  4.8280533e-01.4  4.8280533e-01.5  \
# 0        -0.182047        -0.411866        -0.411866        -0.544813
# 1         0.484376         0.484376         0.484376         0.484376
# 2        -0.462407        -0.462407        -0.462407        -0.462407
# 3         0.483370         0.483370         0.483370         0.483370
# 4        -0.293628        -0.293628        -0.293628        -0.293628
#
#    4.8280533e-01.6  4.8280533e-01.7  ...  1.3383771e+00.34  1.3383771e+00.35  \
# ...

# %%
for i in testing_datasets_list:
    print(f"======================= {i} info: ==============================")
    df = pd.read_csv(TEST_DATA_DIR / i)
    df.info()
    print(f"shape of df : {df.shape}")
# Out:
# ======================= Test_Dst_NoAuction_ZScore_CF_1.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 38397 entries, 4.8382630e-01 to 1.3383771e+00.43
# dtypes: float64(38397)
# memory usage: 43.4 MB
# shape of df : (148, 38397)
# ======================= Test_Dst_NoAuction_ZScore_CF_2.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 28535 entries, 4.7635007e-01 to 1.3392674e+00.241
# dtypes: float64(28535)
# memory usage: 32.2 MB
# shape of df : (148, 28535)
# ======================= Test_Dst_NoAuction_ZScore_CF_3.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 37023 entries, 4.4249060e-01 to 1.2251787e+00.49
# dtypes: float64(37023)
# memory usage: 41.8 MB
# shape of df : (148, 37023)
# ...

# %%
for i in training_datasets_list:
    print(f"======================= {i} info: ==============================")
    df = pd.read_csv(TRAIN_DATA_DIR / i)
    df.info()
    print(f"shape of df : {df.shape}")
# Out:
# ======================= Train_Dst_NoAuction_ZScore_CF_1.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 39512 entries, 4.0827462e-01 to 1.3077480e+00.99
# dtypes: float64(39512)
# memory usage: 44.6 MB
# shape of df : (148, 39512)
# ======================= Train_Dst_NoAuction_ZScore_CF_2.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 77909 entries, 3.3031790e-01 to 1.2606347e+00.43
# dtypes: float64(77909)
# memory usage: 88.0 MB
# shape of df : (148, 77909)
# ======================= Train_Dst_NoAuction_ZScore_CF_3.csv info: ==============================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 106444 entries, 3.0294155e-01 to 1.3020318e+00.241
# dtypes: float64(106444)
# memory usage: 120.2 MB
# shape of df : (148, 106444)
# ...
